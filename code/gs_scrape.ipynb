# %%
import requests

from bs4 import BeautifulSoup

url = 'https://globalcareers-goldmansachs.icims.com/jobs/search?pr=32&searchCategory=44215&searchRelation=keyword_all&mobile=false&width=760&height=4693&bga=true&needsRedirect=false&jan1offset=-300&jun1offset=-240'
#html = response.content
page = requests.get(url)
html = page.text
soup = BeautifulSoup(html)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="js hashchange history rgba no-hsla borderimage borderradius boxshadow opacity fontface video placeholder wf-universltw0165bold-n4-active wf-universltw0167boldcn-n4-active wf-universltw0147lightcn-n4-active wf-universltw0155oblique-n4-active wf-universltw0155roman-n4-active wf-universltw0157condense723821-n4-active wf-universltw0159ultracn-n4-active wf-active" lang="en-US" style="">
#  <head>
#   <!-- <base href="http://www.goldmansachs.com/a/data/jobs/" /> -->
#   <!-- <base href="https://c-8384-20170404-www-goldmansachs-com.i.icims.com" />
# <base href="https://c-7982-20170417-www-goldmansachs-com.i.icims.com" />  -->
#   <base href="https://c-3125-20170418-www-goldmansachs-com.i.icims.com/a/data/jobs/"/>
#   <meta content="IE=Edge" http-equiv="x-ua-compatible"/>
#   <!--[if lt IE 7]>      <html lang="en-US" class="lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
#   <!--[if IE 7]>         <html lang="en-US" class="lt-ie9 lt-ie8"> <![endif]-->
# ...

# %%
import requests

from bs4 import BeautifulSoup


#url = 'https://uscareers-goldmansachs.icims.com/jobs/50398/associate--tech01092019smccbd/job?hub=7'
url = 'https://careers-goldmansachs.icims.com/jobs/50476/engineering-eto---developer-services---deputy-program-manager---core-outreach-and-engagement/job?hub=7&in_iframe=1'
#html = response.content
page = requests.get(url)
html = page.text
soup = BeautifulSoup(html)
title=soup.find('h1' ,class_='iCIMS_Header')
print(title.text)
description=soup.find('div', class_="iCIMS_InfoMsg iCIMS_InfoMsg_Job")
print(description.text)
print(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-ec61825108d3> in <module>
#      11 soup = BeautifulSoup(html)
#      12 title=soup.find('h1' ,class_='iCIMS_Header')
# ---> 13 print(title.text)
#      14 description=soup.find('div', class_="iCIMS_InfoMsg iCIMS_InfoMsg_Job")
#      15 print(description.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests

from bs4 import BeautifulSoup

url = 'https://careers-goldmansachs.icims.com/jobs/50476/engineering-eto---developer-services---deputy-program-manager---core-outreach-and-engagement/job?hub=7&in_iframe=1'
#html = response.content
page = requests.get(url)
html = page.text
soup = BeautifulSoup(html)
soup.find_all('', id="iCIMS")
# Out:
# []
